// %%
import $ivy.`org.apache.spark::spark-connect-client-jvm:4.0.4`

// %%
// change your url as per your session
val url="sc://spark-connect-75a79be6-server.kubeflow-user-example-com.svc.cluster.local:15002"

// %%
import org.apache.spark.sql.SparkSession

val spark = SparkSession.builder()
  .remote(url)
  .getOrCreate()

spark.range(10).show()
